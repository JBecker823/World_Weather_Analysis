# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import gmaps
import time
from datetime import datetime

#import the api key
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Loop through all the cities in the list.
for i, city in enumerate(cities):
#     print("city data line 12")
#     print(city_data)

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
#          # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')       
       # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
#                           "Country" : city_weather["sys"]["country"]
        
#         print(this_city_data)
        #city_data.append({"record_count": record_count})
#         city_data.append(this_city_data)
#         print("city data line 53 ")
#         print(city_data)

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rawson
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | carahue
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | sawtell
# Processing Record 8 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | ushtobe
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | kashi
# Processing Record 13 of Set 1 | tomatlan
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | aklavik
# Processing Record 20 of Set 1 | iisalmi
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | muroto
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | christchurch
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 1 | kiruna
# Processing Record 33 of Set 1 | kinshasa
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | itarema
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | vestmanna
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | havoysund
# Processing Record 43 of Set 1 | husavik
# Processing Record 44 of Set 1 | shelburne
# Processing Record 45 of Set 1 | port said
# Processing Record 46 of Set 1 | quelimane
# Processing Record 47 of Set 1 | huitzuco
# City not found. Skipping...
# Processing Record 48 of Set 1 | kildinstroy
# Processing Record 49 of Set 1 | sitka
# Processing Record 50 of Set 1 | katherine
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | tautira
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | brigantine
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | arlit
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | belen
# Processing Record 12 of Set 2 | arman
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | sistranda
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | aleksandrov gay
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | adeje
# Processing Record 23 of Set 2 | xam nua
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | bonavista
# Processing Record 29 of Set 2 | koslan
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | devils lake
# Processing Record 33 of Set 2 | la ronge
# Processing Record 34 of Set 2 | zhigalovo
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | tucumcari
# Processing Record 39 of Set 2 | porto velho
# Processing Record 40 of Set 2 | kupino
# Processing Record 41 of Set 2 | merauke
# Processing Record 42 of Set 2 | biak
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | acarau
# Processing Record 45 of Set 2 | guanica
# Processing Record 46 of Set 2 | zinder
# Processing Record 47 of Set 2 | the valley
# Processing Record 48 of Set 2 | urumqi
# Processing Record 49 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 2 | cordoba
# Processing Record 1 of Set 3 | hami
# Processing Record 2 of Set 3 | praia da vitoria
# Processing Record 3 of Set 3 | leh
# Processing Record 4 of Set 3 | kajaani
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | caravelas
# Processing Record 7 of Set 3 | tazmalt
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | moron
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | sao joao da barra
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | neiafu
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | half moon bay
# Processing Record 22 of Set 3 | mandera
# Processing Record 23 of Set 3 | cassilandia
# Processing Record 24 of Set 3 | mulki
# Processing Record 25 of Set 3 | abu dhabi
# Processing Record 26 of Set 3 | patnanungan
# Processing Record 27 of Set 3 | catuday
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | zadar
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | lexington park
# Processing Record 32 of Set 3 | ukiah
# Processing Record 33 of Set 3 | kholodnyy
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | carbonear
# Processing Record 37 of Set 3 | salinopolis
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | saintes
# Processing Record 40 of Set 3 | liku
# Processing Record 41 of Set 3 | narasannapeta
# Processing Record 42 of Set 3 | nabire
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | berbera
# Processing Record 45 of Set 3 | garden city
# Processing Record 46 of Set 3 | balkanabat
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | sao caetano de odivelas
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | karaton
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | bethel
# Processing Record 3 of Set 4 | jaciara
# Processing Record 4 of Set 4 | kurmanayevka
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | sumbe
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | dong hoi
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | tateyama
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | bayir
# Processing Record 15 of Set 4 | southbridge
# Processing Record 16 of Set 4 | corumba
# Processing Record 17 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 4 | monopoli
# Processing Record 19 of Set 4 | praia
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | sabaudia
# Processing Record 22 of Set 4 | omsukchan
# Processing Record 23 of Set 4 | kemijarvi
# Processing Record 24 of Set 4 | munirabad
# Processing Record 25 of Set 4 | revda
# Processing Record 26 of Set 4 | zmeinogorsk
# Processing Record 27 of Set 4 | rock springs
# Processing Record 28 of Set 4 | afaahiti
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | north bend
# Processing Record 31 of Set 4 | takoradi
# Processing Record 32 of Set 4 | wanning
# Processing Record 33 of Set 4 | ostersund
# Processing Record 34 of Set 4 | lasa
# Processing Record 35 of Set 4 | elat
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | yurginskoye
# Processing Record 38 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | lujan
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | saurimo
# Processing Record 43 of Set 4 | huilong
# Processing Record 44 of Set 4 | ratnagiri
# Processing Record 45 of Set 4 | karwar
# Processing Record 46 of Set 4 | belmonte
# Processing Record 47 of Set 4 | paamiut
# Processing Record 48 of Set 4 | maniitsoq
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | bathsheba

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
